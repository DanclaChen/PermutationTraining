# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['CUBLAS_WORKSPACE_CONFIG']=':4096:8'
# os.environ["CUDA_VISIBLE_DEVICES"] = "2"


import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from tensorboardX import SummaryWriter

import numpy as np

from tqdm import tqdm
from tqdm import trange

# import math
import matplotlib.pyplot as plt


device = "cuda" if torch.cuda.is_available() else "cpu"

def setup_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
        
        
def output_final(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, test_loss_inf = 0, 0


    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)

#                     test_loss += loss_sup(pred, y).item()
            test_loss += loss_fn(pred, y).item()
            test_loss_inf += torch.linalg.vector_norm(pred-y, ord = float('inf')).item()
#             correct += (pred.argmax(1) == y).type(torch.float).sum().item()
#             correct += (pred == y).type(torch.float).sum().item()
    test_loss /= num_batches
    test_loss_inf /= num_batches
#     correct /= size


    return test_loss, test_loss_inf

# %%
num_sample = 2000
num_train = int(num_sample*0.8)
num_test = int(num_sample*0.2)

adjust_scale = 0

loss_fn = nn.MSELoss()

width_vector = [10, 20, 40, 80, 160, 320]
# width_vector = [40, 80, 160, 320, 640, 1280]

width_vector_2 = [10, 20, 40, 80, 160, 320]

# width_vector = [80, 160, 320, 640, 1280, 2560]

# para_vector = [4, 8, 16, 32]

# width = 640

times_w = 2

times_n = 1

k_period = 5

batch_size = 8

merge = 0

result_matrix = np.zeros((len(width_vector), 10))
result_matrix_infty = np.zeros((len(width_vector), 10))

result_matrix_adj = np.zeros((len(width_vector_2), 10))
result_matrix_infty_adj = np.zeros((len(width_vector_2), 10))

# %%
#generate test set
setup_seed(2022)
Coe = torch.rand(4)
print(Coe)

temp = torch.linspace(-1, 1, num_test)

# for consistency of tensor sizes
x_test = torch.unsqueeze(temp,1)

# # certain function expression: y = sin(\pi x)
y_test = - torch.sin(2 * torch.pi * x_test)
# y_test = Coe[0] + Coe[1] * torch.sin(torch.pi * x_test) + Coe[2] * torch.cos(2 * torch.pi * x_test) + Coe[3] * torch.sin(3 * torch.pi * x_test)
    

# x_test = torch.cat([X_1, X_2], dim=1)
# y_test = torch.unsqueeze(- torch.sin(torch.pi * x_test[:, 0] + torch.pi * x_test[:, 1]), 1)

# create data loaders.
test_set = torch.utils.data.TensorDataset(x_test, y_test)
test_dataloader = DataLoader(test_set, batch_size = num_test, shuffle=False)
# Out:
# tensor([0.3958, 0.9219, 0.7588, 0.3811])

# %%
i = 0

# for times_n in tqdm(para_vector):
for width in tqdm(width_vector):
    
    actual_width = times_w*width

    class NN(nn.Module):
        def __init__(self, layers=[1, actual_width, 1, 1]):
            # First initial the __init__ in nn.Module 
            super(NN, self).__init__()
            
            self.layer1 = nn.Linear(in_features=layers[0], out_features=layers[1])
            self.relu = nn.ReLU()
            self.layer2 = nn.Linear(in_features=layers[1], out_features=layers[2], bias=False)
            self.layer3 = nn.Linear(in_features=layers[2], out_features=layers[3], bias=True)
    #         self.layer3 = nn.Linear(in_features=layers[2], out_features=layers[3], bias=False)
    #         self.layer2 = nn.Linear(in_features=layers[1], out_features=layers[2])



        def forward(self, x):
    #         x = self.flatten(x)
            unacti = self.layer1(x)
            hidden1 = self.relu(unacti)
            hidden2 = self.layer2(hidden1)
            logits = self.layer3(hidden2)

            return logits
        
        
        
    for j in tqdm(range(10)):
        
#         print(i,j)
        
        model = NN().to(device)

        model.load_state_dict(torch.load('Sin-'+str(times_n)+'Xweight-bs'+str(batch_size)+'-k'+str(k_period)+'-adjust'+str(adjust_scale)+'-W'+str(width)+'-iter'+str(j)+'.pth'))
        
        [result_matrix[i, j], result_matrix_infty[i, j]] = output_final(test_dataloader, model, loss_fn)
        
        
        
    i += 1
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:04<00:37,  4.15s/it]
# 100%|██████████| 10/10 [00:04<00:00,  2.30it/s][A
#  17%|█▋        | 1/6 [00:04<00:21,  4.35s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 70.95it/s][A
#  33%|███▎      | 2/6 [00:04<00:07,  1.88s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 48.97it/s][A
#  50%|█████     | 3/6 [00:04<00:03,  1.12s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 85.94it/s][A
#  67%|██████▋   | 4/6 [00:04<00:01,  1.38it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  50%|█████     | 5/10 [00:00<00:00, 46.21it/s]
# 100%|██████████| 10/10 [00:00<00:00, 35.30it/s]
#  83%|████████▎ | 5/6 [00:05<00:00,  1.76it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  40%|████      | 4/10 [00:00<00:00, 34.57it/s]
# 100%|██████████| 10/10 [00:00<00:00, 41.96it/s][A
# 100%|██████████| 6/6 [00:05<00:00,  1.12it/s]

# %%
i = 0

adjust_scale = 10

for width in tqdm(width_vector_2):

    actual_width = times_w*width

    class NN(nn.Module):
        def __init__(self, layers=[1, actual_width, 1, 1]):
            # First initial the __init__ in nn.Module 
            super(NN, self).__init__()

            self.layer1 = nn.Linear(in_features=layers[0], out_features=layers[1])
            self.relu = nn.ReLU()
            self.layer2 = nn.Linear(in_features=layers[1], out_features=layers[2], bias=False)
            self.layer3 = nn.Linear(in_features=layers[2], out_features=layers[3], bias=True)
    #         self.layer3 = nn.Linear(in_features=layers[2], out_features=layers[3], bias=False)
    #         self.layer2 = nn.Linear(in_features=layers[1], out_features=layers[2])



        def forward(self, x):
    #         x = self.flatten(x)
            unacti = self.layer1(x)
            hidden1 = self.relu(unacti)
            hidden2 = self.layer2(hidden1)
            logits = self.layer3(hidden2)

            return logits

    for j in tqdm(range(10)):

#         print(i,j)

        model = NN().to(device)

        model.load_state_dict(torch.load('Sin-'+str(times_n)+'Xweight-bs'+str(batch_size)+'k'+str(k_period)+'-adjust'+str(adjust_scale)+'-W'+str(width)+'-iter'+str(j)+'.pth'))

        [result_matrix_adj[i, j], result_matrix_infty_adj[i, j]] = output_final(test_dataloader, model, loss_fn)

        
    i += 1
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 87.67it/s]
#  17%|█▋        | 1/6 [00:00<00:00,  8.29it/s]
# 100%|██████████| 10/10 [00:00<00:00, 103.04it/s]
#  33%|███▎      | 2/6 [00:00<00:00,  9.17it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 37.68it/s][A
#  50%|█████     | 3/6 [00:00<00:00,  5.49it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 80.11it/s][A
#  67%|██████▋   | 4/6 [00:00<00:00,  6.18it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 81.36it/s][A
#  83%|████████▎ | 5/6 [00:00<00:00,  6.65it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# 100%|██████████| 10/10 [00:00<00:00, 87.43it/s][A
# 100%|██████████| 6/6 [00:00<00:00,  6.87it/s]

# %%
from statistics import geometric_mean

x = width_vector

# print(np.shape(result_matrix))

# print(geometric_mean(result_matrix[0]))

# print(np.average(result_matrix, axis=1))

mean = np.zeros(int(len(x)))
mean_infty = np.zeros(int(len(x)))

# print(type(mean))

# print(mean[0])

for i in range(len(x)):
    mean[i] = geometric_mean(result_matrix[i])
    mean_infty[i] = geometric_mean(result_matrix_infty[i])

# mean = np.average(result_matrix, axis=1)

# print(mean)
# print(mean_infty)

# mean = geometric_mean(result_matrix, axis=1)

y_max = np.max(result_matrix, axis = 1)
y_min = np.min(result_matrix, axis = 1)

# yerr = np.vstack((y_min, y_max))
yerr = np.abs(np.vstack((y_min, y_max)) - mean)


y_max_infty = np.max(result_matrix_infty, axis = 1)
y_min_infty = np.min(result_matrix_infty, axis = 1)

# yerr_infty = np.vstack((y_min_infty, y_max_infty))
yerr_infty = np.abs(np.vstack((y_min_infty, y_max_infty)) - mean_infty)

# with adjust

x2 = width_vector_2

# print(np.shape(result_matrix_adj))

print(result_matrix_infty_adj)

# print(geometric_mean(result_matrix_adj[0]))

# print(np.average(result_matrix, axis=1))

mean2 = np.zeros(int(len(x2)))
mean_infty2 = np.zeros(int(len(x2)))

# print(type(mean2))

# print(mean2[0])

for i in range(len(x2)):
    mean2[i] = geometric_mean(result_matrix_adj[i])
    mean_infty2[i] = geometric_mean(result_matrix_infty_adj[i])

# mean = np.average(result_matrix, axis=1)

print(mean_infty2)

# mean = geometric_mean(result_matrix, axis=1)

y_max2 = np.max(result_matrix_adj, axis = 1)
y_min2 = np.min(result_matrix_adj, axis = 1)

# yerr2 = np.vstack((y_min2, y_max2))
yerr2 = np.abs(np.vstack((y_min2, y_max2)) - mean2)

y_max_infty2 = np.max(result_matrix_infty_adj, axis = 1)
y_min_infty2 = np.min(result_matrix_infty_adj, axis = 1)

# yerr_infty2 = np.vstack((y_min_infty2, y_max_infty2))
yerr_infty2 = np.abs(np.vstack((y_min_infty2, y_max_infty2)) - mean_infty2)

print('y_max_infty2'+str(y_max_infty2))
print('y_min_infty2'+str(y_min_infty2))
print('yerr_infty2'+str(yerr_infty2))






# print(yerr2)
begin_point = 5E-1

x_ref = [x[0], x[-1]]
y_ref = [begin_point, begin_point/np.sqrt(np.power(2,len(x)))]

# print(np.max(result_matrix, axis = 1))
# print(np.min(result_matrix, axis = 1))

ax = plt.figure(figsize=(8, 6))
# plt.errorbar(x, mean, yerr=yerr, capsize = 3, label='adj = 0, MSE error')
plt.errorbar(x, mean_infty, yerr=yerr_infty, capsize = 3, label='adj = 0, $L^\infty$ error')

# plt.errorbar(x2, mean2, yerr=yerr2, capsize = 3, label='adj = 10, MSE error')
plt.errorbar(x2, mean_infty2, yerr=yerr_infty2, capsize = 3, label='adj = 10, $L^\infty$ error')
plt.plot(x_ref, y_ref, linestyle='--', label='1/2 order')
plt.yscale('log')
# plt.ylim((1e-9,1))
plt.xscale('log')
plt.xlabel('n', size=20)
# plt.ylabel('Loss', size=15)
plt.legend(fontsize=15)
# ax.set_xticks(x)
plt.xticks(x, x, fontsize=15)
plt.yticks(fontsize=15)
# ax()
plt.savefig('plot.pdf', bbox_inches='tight')
plt.show()
# Out:
# [[1.08005416 0.25214556 0.77162522 0.75154519 0.66448933 1.06131577
#   1.23886371 0.79285622 0.71280086 0.6641885 ]
#  [0.43244079 0.85039717 0.3839235  0.74355698 0.67433822 0.3852188
#   0.55365044 0.85784799 0.86955416 0.42480081]
#  [0.2254557  0.27607042 0.23559898 0.18853518 0.47679427 0.12580961
#   0.19420749 0.36084181 0.41895902 0.32095477]
#  [0.28789026 0.21041718 0.23456448 0.12047097 0.34172127 0.07411462
#   0.32977849 0.26322165 0.33890051 0.26630995]
#  [0.19443734 0.06190927 0.24581236 0.12588182 0.0770906  0.05820203
#   0.31779763 0.05943114 0.12431557 0.2289966 ]
#  [0.10895319 0.0740717  0.10190336 0.15190853 0.07867978 0.19883539
#   0.13356245 0.05502455 0.14132889 0.21169084]]
# [0.74374979 0.58611396 0.26265701 0.22547751 0.12455354 0.11569627]
# y_max_infty2[1.23886371 0.86955416 0.47679427 0.34172127 0.31779763 0.21169084]
# y_min_infty2[0.25214556 0.3839235  0.12580961 0.07411462 0.05820203 0.05502455]
# yerr_infty2[[0.49160423 0.20219045 0.1368474  0.15136289 0.06635151 0.06067172]
#  [0.49511392 0.28344021 0.21413726 0.11624376 0.19324409 0.09599457]]

# %%
    
    
    
with torch.no_grad():
#         for X, y in test_dataloader:
#             X, y = X.to(device), y.to(device)
#             pred = model(X)
    X_test = x_test.to(device)
    Y_pred = model(X_test)

    y_pred = Y_pred.cpu().detach().numpy()
    
#     print(y_pred)
    
# print(y_pred.type(), y_pred.shape)

ax = plt.figure(figsize=(8, 6))

plt.plot(x_test.cpu().detach().numpy(), y_test.cpu().detach().numpy(), marker="*", markersize=3., linestyle="None", label='Data')
plt.plot(x_test.cpu().detach().numpy(), y_pred, label='n = 20')
plt.xlabel('x', fontsize=20)
plt.ylabel('y', fontsize=20)
plt.legend(fontsize=15)
# plt.title('n = 20')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.savefig('plot.pdf', bbox_inches='tight')
plt.show()
